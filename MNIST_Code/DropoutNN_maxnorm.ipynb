# %%
import tensorflow as tf
import time
from maxout import max_out

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# 5*240 neurons in each hidden layers
n_hidden_1 = 1200
n_hidden_2 = 1200

# input size is the size of a picture: 28*28
# output size
input_size = 784
output_size = 10

# Parameters
learning_rate = 0.0005
training_epochs = 1000
batch_size = 200
display_step = 1

# %%
def layer_maxout(x, weight_shape, bias_shape):
    """
    Defines the network layers
    input:
        - x: input vector of the layer
        - weight_shape: shape the the weight maxtrix
        - bias_shape: shape of the bias vector
    output:
        - output vector of the layer after the matrix multiplication and transformation
    """
    
    weight_init = tf.random_normal_initializer(stddev=(2.0/weight_shape[0])**0.5)
    W = tf.get_variable("W", weight_shape, initializer=weight_init,constraint = tf.keras.constraints.MaxNorm(4))
    
    bias_init = tf.constant_initializer(value=0)
    b = tf.get_variable("b", bias_shape, initializer=bias_init)
    
    return max_out(tf.matmul(x, W) + b,240)

# %%
def layer(x, weight_shape, bias_shape):
    """
    Defines the network layers
    input:
        - x: input vector of the layer
        - weight_shape: shape the the weight maxtrix
        - bias_shape: shape of the bias vector
    output:
        - output vector of the layer after the matrix multiplication and transformation
    """
    
    weight_init = tf.random_normal_initializer(stddev=(2.0/weight_shape[0])**0.5)
    W = tf.get_variable("W", weight_shape, initializer=weight_init,constraint = tf.keras.constraints.MaxNorm(4))
    
    bias_init = tf.constant_initializer(value=0)
    b = tf.get_variable("b", bias_shape, initializer=bias_init)
    
    return tf.nn.relu(tf.matmul(x, W) + b)

# %%
def inference(x, keep_prob):
    """
    define the structure of the whole network
    input:
        - x: a batch of pictures 
        (input shape = (batch_size*image_size))
        - keep_prob: The keep_prob of dropout layer
    output:
        - a batch vector corresponding to the logits predicted by the network
        (output shape = (batch_size*output_size)) 
    """
    x = tf.cond(keep_prob<1,lambda:tf.nn.dropout(x,0.8),lambda:x)
    x = tf.reshape(x,[-1,28,28,1])

    with tf.variable_scope("fully_connected1"):
        
        # pass the output of max-pooling into a Fully_Connected layer
        x = tf.reshape(x,[-1,28*28])
        # after reshaping, use fully-connected layer to compress
        fc_1 = layer_maxout(x, [28*28, n_hidden_1], [n_hidden_1])
        
        # apply dropout. You may try to add drop out after every pooling layer.
        # outputs the input element scaled up by 1/keep_prob
        # The scaling is so that the expected sum is unchanged
        fc_1_drop = tf.nn.dropout(fc_1, keep_prob)
    
    with tf.variable_scope("fully_connected2"):
        
        # pass the output of max-pooling into a Fully_Connected layer

        # after reshaping, use fully-connected layer to compress
        fc_2 = layer_maxout(fc_1_drop, [n_hidden_1/5, n_hidden_2], [n_hidden_2])
        
        # apply dropout. You may try to add drop out after every pooling layer.
        # outputs the input element scaled up by 1/keep_prob
        # The scaling is so that the expected sum is unchanged
        fc_2_drop = tf.nn.dropout(fc_2, keep_prob)

    with tf.variable_scope("output"):
        output = layer(fc_2_drop, [n_hidden_2/5, 10], [10])

    return output

# %%
def loss(output, y):
    """
    Computes softmax cross entropy between logits and labels and then the loss 
    
    intput:
        - output: the output of the inference function 
        - y: true value of the sample batch
        
        the two have the same shape (batch_size * num_of_classes)
    output:
        - loss: loss of the corresponding batch (scalar tensor)
    
    """
    xentropy = tf.nn.softmax_cross_entropy_with_logits(logits=output, labels=y)    
    loss = tf.reduce_mean(xentropy)
    return loss

# %%
def training(cost, global_step):
    """
    defines the necessary elements to train the network
    
    intput:
        - cost: the cost is the loss of the corresponding batch
        - global_step: number of batch seen so far, it is incremented by one each time the .minimize() function is called
    """
    tf.summary.scalar("cost", cost)
    # using Adam Optimizer 
    optimizer = tf.train.AdamOptimizer(learning_rate)
    #grads = optimizer.compute_gradients(cost)
    #for i, (g,v) in enumerate(grads):
    #    grads[i] = (tf.clip_by_norm(g,3.5),v)
    #train_op = optimizer.apply_gradients(grads, global_step=global_step)
    train_op = optimizer.minimize(cost, global_step=global_step)
    return train_op

# %%
def evaluate(output, y):
    """
    evaluates the accuracy on the validation set 
    input:
        -output: prediction vector of the network for the validation set
        -y: true value for the validation set
    output:
        - accuracy: accuracy on the validation set (scalar between 0 and 1)
    """
    #correct prediction is a binary vector which equals one when the output and y match
    #otherwise the vector equals 0
    #tf.cast: change the type of a tensor into another one
    #then, by taking the mean of the tensor, we directly have the average score, so the accuracy
    
    correct_prediction = tf.equal(tf.argmax(output, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    tf.summary.scalar("validation_error", (1.0 - accuracy))
    return accuracy

# %%
earlystop_cnt = 0
earlystop_threshold = 16
if __name__ == '__main__':
    
    #please, make sure you changed for your own path 
    log_files_path = 'C:/Users/WeiLiu/logs/CNNs/'
    start_time = time.time()
    
    with tf.Graph().as_default():

        with tf.variable_scope("MNIST_DropoutNNRelu_maxnorm_model"):
            #neural network definition
            
            #the input variables are first define as placeholder 
            # a placeholder is a variable/data which will be assigned later 
            # MNIST data image of shape 28*28=784
            x = tf.placeholder("float", [None, 784]) 
            # 0-9 digits recognition
            y = tf.placeholder("float", [None, 10])  
            
            # dropout probability
            keep_prob = tf.placeholder(tf.float32) 
            #the network is defined using the inference function defined above in the code
            output = inference(x, keep_prob)
            cost = loss(output, y)
            #initialize the value of the global_step variable 
            # recall: it is incremented by one each time the .minimise() is called
            global_step = tf.Variable(0, name='global_step', trainable=False)
            train_op = training(cost, global_step)
            #evaluate the accuracy of the network (done on a validation set)
            eval_op = evaluate(output, y)
            summary_op = tf.summary.merge_all()
            saver = tf.train.Saver()
            sess = tf.Session()
            
            summary_writer = tf.summary.FileWriter(log_files_path, sess.graph)
            init_op = tf.global_variables_initializer()
            sess.run(init_op)
            
            
            total_batch = int(mnist.train.num_examples/batch_size)
            max_val_acc = 0.0
            prev_cost = 0.0
            
            # Training cycle
            for epoch in range(training_epochs):

                avg_cost = 0.0
                
                # Loop over all batches
                for i in range(total_batch):
                    
                    minibatch_x, minibatch_y = mnist.train.next_batch(batch_size)
                    
                    # Fit training using batch data
                    sess.run(train_op, feed_dict={x: minibatch_x, y: minibatch_y, keep_prob: 0.5})
                    
                    # Compute average loss
                    avg_cost += sess.run(cost, feed_dict={x: minibatch_x, y: minibatch_y, keep_prob: 0.5})/total_batch
                    
                
                # Display logs per epoch step
                if epoch % display_step == 0:
                    
                    print("Epoch:", '%04d' % (epoch+1), "cost =", "{:0.9f}".format(avg_cost))
                    
                    #probability dropout of 1 during validation
                    accuracy_val = sess.run(eval_op, feed_dict={x: mnist.validation.images, y: mnist.validation.labels, keep_prob: 1})
                    print("Validation Error:", (1 - accuracy_val))
                    
                    if accuracy_val < max_val_acc:
                        if (avg_cost < prev_cost):
                            if earlystop_cnt == earlystop_threshold:
                                print("early stopped on" + str(epoch))
                                break
                            else:
                                print("overfitting warning:" + str(earlystop_cnt))
                                earlystop_cnt += 1
                        else:
                            earlystop_cnt = 0
                    else:
                        earlystop_cnt = 0
                        max_val_acc = accuracy_val
                        
                    prev_cost = avg_cost
                    
                    # probability dropout of 0.25 during training
                    summary_str = sess.run(summary_op, feed_dict={x: minibatch_x, y: minibatch_y, keep_prob: 0.5})
                    summary_writer.add_summary(summary_str, sess.run(global_step))
                    
                    saver.save(sess, log_files_path+'model-checkpoint', global_step=global_step)
                    
            print("Optimization Done")
                    
            accuracy = sess.run(eval_op, feed_dict={x: mnist.test.images, y: mnist.test.labels, keep_prob: 1})
            print("Test Accuracy:", accuracy)
                    
        elapsed_time = time.time() - start_time
        print('Execution time was %0.3f' % elapsed_time)
# Out:
# Epoch: 0001 cost = 2.094841647
# Validation Error: 0.256399989128
# Epoch: 0002 cost = 0.585251879
# Validation Error: 0.0469999909401
# Epoch: 0003 cost = 0.298881165
# Validation Error: 0.0374000072479
# Epoch: 0004 cost = 0.239827930
# Validation Error: 0.0314000248909
# Epoch: 0005 cost = 0.197133813
# Validation Error: 0.0278000235558
# Epoch: 0006 cost = 0.172258625
# Validation Error: 0.0256000161171
# Epoch: 0007 cost = 0.153605135
# Validation Error: 0.0221999883652
# Epoch: 0008 cost = 0.138847135
# Validation Error: 0.0206000208855
# Epoch: 0009 cost = 0.131160971
# Validation Error: 0.0188000202179
# Epoch: 0010 cost = 0.120204206
# Validation Error: 0.0163999795914
# Epoch: 0011 cost = 0.113883973
# Validation Error: 0.0180000066757
# overfitting warning:0
# Epoch: 0012 cost = 0.104447685
# Validation Error: 0.0162000060081
# Epoch: 0013 cost = 0.097113721
# Validation Error: 0.0157999992371
# Epoch: 0014 cost = 0.093153260
# Validation Error: 0.0157999992371
# Epoch: 0015 cost = 0.088957570
# Validation Error: 0.0156000256538
# Epoch: 0016 cost = 0.088096553
# Validation Error: 0.0163999795914
# overfitting warning:0
# Epoch: 0017 cost = 0.079716544
# Validation Error: 0.0152000188828
# Epoch: 0018 cost = 0.077839107
# Validation Error: 0.0163999795914
# overfitting warning:0
# Epoch: 0019 cost = 0.076105204
# Validation Error: 0.0141999721527
# Epoch: 0020 cost = 0.071724325
# Validation Error: 0.015399992466
# overfitting warning:0
# Epoch: 0021 cost = 0.069019430
# Validation Error: 0.0139999985695
# Epoch: 0022 cost = 0.066494135
# Validation Error: 0.0134000182152
# Epoch: 0023 cost = 0.065379601
# Validation Error: 0.0139999985695
# overfitting warning:0
# Epoch: 0024 cost = 0.062913648
# Validation Error: 0.0134000182152
# Epoch: 0025 cost = 0.061880546
# Validation Error: 0.015399992466
# overfitting warning:0
# Epoch: 0026 cost = 0.057233593
# Validation Error: 0.0144000053406
# overfitting warning:1
# Epoch: 0027 cost = 0.057794710
# Validation Error: 0.0121999979019
# Epoch: 0028 cost = 0.057022741
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0029 cost = 0.055181151
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0030 cost = 0.058516634
# Validation Error: 0.0135999917984
# Epoch: 0031 cost = 0.051701345
# Validation Error: 0.0131999850273
# overfitting warning:0
# Epoch: 0032 cost = 0.051777052
# Validation Error: 0.0130000114441
# Epoch: 0033 cost = 0.051781774
# Validation Error: 0.0131999850273
# Epoch: 0034 cost = 0.049936519
# Validation Error: 0.0120000243187
# Epoch: 0035 cost = 0.048830793
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0036 cost = 0.046552041
# Validation Error: 0.0117999911308
# Epoch: 0037 cost = 0.045996346
# Validation Error: 0.0134000182152
# overfitting warning:0
# Epoch: 0038 cost = 0.044867159
# Validation Error: 0.0123999714851
# overfitting warning:1
# Epoch: 0039 cost = 0.043468061
# Validation Error: 0.0116000175476
# Epoch: 0040 cost = 0.043041371
# Validation Error: 0.0116000175476
# Epoch: 0041 cost = 0.040591566
# Validation Error: 0.0131999850273
# overfitting warning:0
# Epoch: 0042 cost = 0.040173200
# Validation Error: 0.0130000114441
# overfitting warning:1
# Epoch: 0043 cost = 0.039816845
# Validation Error: 0.0120000243187
# overfitting warning:2
# Epoch: 0044 cost = 0.038696641
# Validation Error: 0.0121999979019
# overfitting warning:3
# Epoch: 0045 cost = 0.039230215
# Validation Error: 0.0121999979019
# Epoch: 0046 cost = 0.038711584
# Validation Error: 0.0141999721527
# overfitting warning:0
# Epoch: 0047 cost = 0.039961233
# Validation Error: 0.0131999850273
# Epoch: 0048 cost = 0.036830156
# Validation Error: 0.0135999917984
# overfitting warning:0
# Epoch: 0049 cost = 0.035491442
# Validation Error: 0.0116000175476
# Epoch: 0050 cost = 0.036439527
# Validation Error: 0.0120000243187
# Epoch: 0051 cost = 0.035803253
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0052 cost = 0.035514615
# Validation Error: 0.0116000175476
# Epoch: 0053 cost = 0.034093687
# Validation Error: 0.0116000175476
# Epoch: 0054 cost = 0.036266840
# Validation Error: 0.0116000175476
# Epoch: 0055 cost = 0.035171588
# Validation Error: 0.0112000107765
# Epoch: 0056 cost = 0.034775039
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0057 cost = 0.031263924
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0058 cost = 0.030355913
# Validation Error: 0.0120000243187
# overfitting warning:2
# Epoch: 0059 cost = 0.035066617
# Validation Error: 0.0130000114441
# Epoch: 0060 cost = 0.033273204
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0061 cost = 0.031513061
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0062 cost = 0.031209946
# Validation Error: 0.0123999714851
# overfitting warning:2
# Epoch: 0063 cost = 0.028449559
# Validation Error: 0.0116000175476
# overfitting warning:3
# Epoch: 0064 cost = 0.031497985
# Validation Error: 0.00999999046326
# Epoch: 0065 cost = 0.030509670
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0066 cost = 0.030004813
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0067 cost = 0.030045960
# Validation Error: 0.0117999911308
# Epoch: 0068 cost = 0.028322573
# Validation Error: 0.0127999782562
# overfitting warning:0
# Epoch: 0069 cost = 0.030567197
# Validation Error: 0.0120000243187
# Epoch: 0070 cost = 0.028862491
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0071 cost = 0.027635632
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0072 cost = 0.027836787
# Validation Error: 0.0116000175476
# Epoch: 0073 cost = 0.027762182
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0074 cost = 0.028372900
# Validation Error: 0.0105999708176
# Epoch: 0075 cost = 0.025488281
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0076 cost = 0.026175797
# Validation Error: 0.0120000243187
# Epoch: 0077 cost = 0.026805547
# Validation Error: 0.0116000175476
# Epoch: 0078 cost = 0.024711987
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0079 cost = 0.027025556
# Validation Error: 0.0103999972343
# Epoch: 0080 cost = 0.025390206
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0081 cost = 0.027090928
# Validation Error: 0.0117999911308
# Epoch: 0082 cost = 0.025811569
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0083 cost = 0.025648131
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0084 cost = 0.025727652
# Validation Error: 0.0108000040054
# Epoch: 0085 cost = 0.025771322
# Validation Error: 0.0102000236511
# Epoch: 0086 cost = 0.024872921
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0087 cost = 0.024271536
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0088 cost = 0.025738472
# Validation Error: 0.0130000114441
# Epoch: 0089 cost = 0.023197478
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0090 cost = 0.024350754
# Validation Error: 0.0105999708176
# Epoch: 0091 cost = 0.025707995
# Validation Error: 0.0116000175476
# Epoch: 0092 cost = 0.021833615
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0093 cost = 0.023360368
# Validation Error: 0.0120000243187
# Epoch: 0094 cost = 0.025695327
# Validation Error: 0.0127999782562
# Epoch: 0095 cost = 0.022014843
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0096 cost = 0.024688526
# Validation Error: 0.0109999775887
# Epoch: 0097 cost = 0.025514301
# Validation Error: 0.0105999708176
# Epoch: 0098 cost = 0.021672300
# Validation Error: 0.00980001688004
# Epoch: 0099 cost = 0.021367969
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0100 cost = 0.023553205
# Validation Error: 0.012600004673
# Epoch: 0101 cost = 0.023550669
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0102 cost = 0.022692888
# Validation Error: 0.0105999708176
# overfitting warning:1
# Epoch: 0103 cost = 0.021464921
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0104 cost = 0.022940229
# Validation Error: 0.00999999046326
# Epoch: 0105 cost = 0.022574088
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0106 cost = 0.022251395
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0107 cost = 0.020014387
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0108 cost = 0.021719861
# Validation Error: 0.0108000040054
# Epoch: 0109 cost = 0.023051267
# Validation Error: 0.0113999843597
# Epoch: 0110 cost = 0.022451629
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0111 cost = 0.022431423
# Validation Error: 0.0109999775887
# overfitting warning:1
# Epoch: 0112 cost = 0.022203612
# Validation Error: 0.0102000236511
# overfitting warning:2
# Epoch: 0113 cost = 0.021879743
# Validation Error: 0.0105999708176
# overfitting warning:3
# Epoch: 0114 cost = 0.019128852
# Validation Error: 0.0109999775887
# overfitting warning:4
# Epoch: 0115 cost = 0.020558573
# Validation Error: 0.0109999775887
# Epoch: 0116 cost = 0.020713641
# Validation Error: 0.0103999972343
# Epoch: 0117 cost = 0.020203454
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0118 cost = 0.020535336
# Validation Error: 0.0109999775887
# Epoch: 0119 cost = 0.019612452
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0120 cost = 0.019042258
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0121 cost = 0.021296648
# Validation Error: 0.0105999708176
# Epoch: 0122 cost = 0.020344120
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0123 cost = 0.019024308
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0124 cost = 0.021277872
# Validation Error: 0.0112000107765
# Epoch: 0125 cost = 0.021373748
# Validation Error: 0.0116000175476
# Epoch: 0126 cost = 0.020454948
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0127 cost = 0.020493715
# Validation Error: 0.0108000040054
# Epoch: 0128 cost = 0.022487409
# Validation Error: 0.0109999775887
# Epoch: 0129 cost = 0.021222008
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0130 cost = 0.019983423
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0131 cost = 0.019415964
# Validation Error: 0.0117999911308
# overfitting warning:2
# Epoch: 0132 cost = 0.019372355
# Validation Error: 0.0116000175476
# overfitting warning:3
# Epoch: 0133 cost = 0.021947783
# Validation Error: 0.0121999979019
# Epoch: 0134 cost = 0.019405964
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0135 cost = 0.021134548
# Validation Error: 0.0102000236511
# Epoch: 0136 cost = 0.019636812
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0137 cost = 0.020129056
# Validation Error: 0.0112000107765
# Epoch: 0138 cost = 0.019209970
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0139 cost = 0.019056737
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0140 cost = 0.018833603
# Validation Error: 0.0112000107765
# overfitting warning:2
# Epoch: 0141 cost = 0.018830073
# Validation Error: 0.0116000175476
# overfitting warning:3
# Epoch: 0142 cost = 0.018930715
# Validation Error: 0.0116000175476
# Epoch: 0143 cost = 0.020496400
# Validation Error: 0.0108000040054
# Epoch: 0144 cost = 0.020687772
# Validation Error: 0.0108000040054
# Epoch: 0145 cost = 0.018347501
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0146 cost = 0.018494237
# Validation Error: 0.00959998369217
# Epoch: 0147 cost = 0.018613532
# Validation Error: 0.0112000107765
# Epoch: 0148 cost = 0.017448632
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0149 cost = 0.017777718
# Validation Error: 0.0112000107765
# Epoch: 0150 cost = 0.017889148
# Validation Error: 0.0116000175476
# Epoch: 0151 cost = 0.018940244
# Validation Error: 0.012600004673
# Epoch: 0152 cost = 0.019089436
# Validation Error: 0.0109999775887
# Epoch: 0153 cost = 0.017530463
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0154 cost = 0.017829103
# Validation Error: 0.0123999714851
# Epoch: 0155 cost = 0.017007658
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0156 cost = 0.018193292
# Validation Error: 0.0108000040054
# Epoch: 0157 cost = 0.018512679
# Validation Error: 0.012600004673
# Epoch: 0158 cost = 0.017574899
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0159 cost = 0.017645379
# Validation Error: 0.0108000040054
# Epoch: 0160 cost = 0.016429822
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0161 cost = 0.018702117
# Validation Error: 0.0112000107765
# Epoch: 0162 cost = 0.017784215
# Validation Error: 0.00980001688004
# overfitting warning:0
# Epoch: 0163 cost = 0.019124779
# Validation Error: 0.0105999708176
# Epoch: 0164 cost = 0.017629397
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0165 cost = 0.019213534
# Validation Error: 0.0123999714851
# Epoch: 0166 cost = 0.015942244
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0167 cost = 0.017819532
# Validation Error: 0.0103999972343
# Epoch: 0168 cost = 0.017444512
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0169 cost = 0.017243069
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0170 cost = 0.018159066
# Validation Error: 0.0103999972343
# Epoch: 0171 cost = 0.018012784
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0172 cost = 0.018360668
# Validation Error: 0.0120000243187
# Epoch: 0173 cost = 0.019594350
# Validation Error: 0.0103999972343
# Epoch: 0174 cost = 0.018097309
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0175 cost = 0.016769618
# Validation Error: 0.0102000236511
# overfitting warning:1
# Epoch: 0176 cost = 0.018452902
# Validation Error: 0.0113999843597
# Epoch: 0177 cost = 0.016299177
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0178 cost = 0.016640045
# Validation Error: 0.0112000107765
# Epoch: 0179 cost = 0.017024570
# Validation Error: 0.0102000236511
# Epoch: 0180 cost = 0.017999861
# Validation Error: 0.0116000175476
# Epoch: 0181 cost = 0.015086081
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0182 cost = 0.016318793
# Validation Error: 0.0117999911308
# Epoch: 0183 cost = 0.015446522
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0184 cost = 0.019558339
# Validation Error: 0.0120000243187
# Epoch: 0185 cost = 0.015865526
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0186 cost = 0.017703804
# Validation Error: 0.0116000175476
# Epoch: 0187 cost = 0.017447619
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0188 cost = 0.015717136
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0189 cost = 0.016087322
# Validation Error: 0.0116000175476
# Epoch: 0190 cost = 0.016688750
# Validation Error: 0.0108000040054
# Epoch: 0191 cost = 0.016375497
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0192 cost = 0.015861850
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0193 cost = 0.016935644
# Validation Error: 0.0109999775887
# Epoch: 0194 cost = 0.016916701
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0195 cost = 0.016040123
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0196 cost = 0.015943918
# Validation Error: 0.00999999046326
# overfitting warning:2
# Epoch: 0197 cost = 0.015320288
# Validation Error: 0.0102000236511
# overfitting warning:3
# Epoch: 0198 cost = 0.017082235
# Validation Error: 0.0117999911308
# Epoch: 0199 cost = 0.017261846
# Validation Error: 0.0113999843597
# Epoch: 0200 cost = 0.014308463
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0201 cost = 0.016144421
# Validation Error: 0.0123999714851
# Epoch: 0202 cost = 0.014962850
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0203 cost = 0.014837914
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0204 cost = 0.017639010
# Validation Error: 0.0120000243187
# Epoch: 0205 cost = 0.015671735
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0206 cost = 0.014607062
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0207 cost = 0.016585532
# Validation Error: 0.0130000114441
# Epoch: 0208 cost = 0.016337039
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0209 cost = 0.015231092
# Validation Error: 0.0109999775887
# overfitting warning:1
# Epoch: 0210 cost = 0.016318835
# Validation Error: 0.0116000175476
# Epoch: 0211 cost = 0.013952461
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0212 cost = 0.017315210
# Validation Error: 0.0121999979019
# Epoch: 0213 cost = 0.014803565
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0214 cost = 0.015118018
# Validation Error: 0.0121999979019
# Epoch: 0215 cost = 0.016330552
# Validation Error: 0.0116000175476
# Epoch: 0216 cost = 0.016207090
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0217 cost = 0.015895659
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0218 cost = 0.015840618
# Validation Error: 0.0116000175476
# overfitting warning:2
# Epoch: 0219 cost = 0.015965277
# Validation Error: 0.012600004673
# Epoch: 0220 cost = 0.015761924
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0221 cost = 0.015347287
# Validation Error: 0.0108000040054
# overfitting warning:1
# Epoch: 0222 cost = 0.015728038
# Validation Error: 0.0102000236511
# Epoch: 0223 cost = 0.014945505
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0224 cost = 0.014465749
# Validation Error: 0.0108000040054
# overfitting warning:1
# Epoch: 0225 cost = 0.013236294
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0226 cost = 0.014826219
# Validation Error: 0.0117999911308
# Epoch: 0227 cost = 0.015552122
# Validation Error: 0.0105999708176
# Epoch: 0228 cost = 0.013900751
# Validation Error: 0.0127999782562
# overfitting warning:0
# Epoch: 0229 cost = 0.014744480
# Validation Error: 0.0113999843597
# Epoch: 0230 cost = 0.015209809
# Validation Error: 0.0116000175476
# Epoch: 0231 cost = 0.014726652
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0232 cost = 0.016629169
# Validation Error: 0.0108000040054
# Epoch: 0233 cost = 0.015054724
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0234 cost = 0.014579738
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0235 cost = 0.015106083
# Validation Error: 0.0105999708176
# Epoch: 0236 cost = 0.014876892
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0237 cost = 0.015005647
# Validation Error: 0.0112000107765
# Epoch: 0238 cost = 0.015851437
# Validation Error: 0.0113999843597
# Epoch: 0239 cost = 0.014862031
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0240 cost = 0.015702338
# Validation Error: 0.0123999714851
# Epoch: 0241 cost = 0.016048713
# Validation Error: 0.0120000243187
# Epoch: 0242 cost = 0.015985242
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0243 cost = 0.015887831
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0244 cost = 0.011987760
# Validation Error: 0.0120000243187
# overfitting warning:2
# Epoch: 0245 cost = 0.017494553
# Validation Error: 0.0112000107765
# Epoch: 0246 cost = 0.015887342
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0247 cost = 0.015317690
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0248 cost = 0.015106646
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0249 cost = 0.014718669
# Validation Error: 0.0120000243187
# overfitting warning:3
# Epoch: 0250 cost = 0.016018421
# Validation Error: 0.0112000107765
# Epoch: 0251 cost = 0.014319996
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0252 cost = 0.015150314
# Validation Error: 0.0116000175476
# Epoch: 0253 cost = 0.016295166
# Validation Error: 0.0127999782562
# Epoch: 0254 cost = 0.017341893
# Validation Error: 0.0116000175476
# Epoch: 0255 cost = 0.012967397
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0256 cost = 0.014855844
# Validation Error: 0.0109999775887
# Epoch: 0257 cost = 0.014758140
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0258 cost = 0.016178355
# Validation Error: 0.0105999708176
# Epoch: 0259 cost = 0.012785461
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0260 cost = 0.014554454
# Validation Error: 0.0127999782562
# Epoch: 0261 cost = 0.015410322
# Validation Error: 0.0112000107765
# Epoch: 0262 cost = 0.015420198
# Validation Error: 0.012600004673
# Epoch: 0263 cost = 0.016222755
# Validation Error: 0.012600004673
# Epoch: 0264 cost = 0.013719967
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0265 cost = 0.016322451
# Validation Error: 0.0113999843597
# Epoch: 0266 cost = 0.015501876
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0267 cost = 0.013215647
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0268 cost = 0.016516897
# Validation Error: 0.0116000175476
# Epoch: 0269 cost = 0.014996829
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0270 cost = 0.014771658
# Validation Error: 0.0130000114441
# overfitting warning:1
# Epoch: 0271 cost = 0.013097126
# Validation Error: 0.0120000243187
# overfitting warning:2
# Epoch: 0272 cost = 0.013379511
# Validation Error: 0.0117999911308
# Epoch: 0273 cost = 0.011827700
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0274 cost = 0.012579938
# Validation Error: 0.0116000175476
# Epoch: 0275 cost = 0.014669475
# Validation Error: 0.0116000175476
# Epoch: 0276 cost = 0.012944287
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0277 cost = 0.015119126
# Validation Error: 0.0109999775887
# Epoch: 0278 cost = 0.013673227
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0279 cost = 0.012982037
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0280 cost = 0.016528517
# Validation Error: 0.0123999714851
# Epoch: 0281 cost = 0.014360736
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0282 cost = 0.013765451
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0283 cost = 0.015045893
# Validation Error: 0.0113999843597
# Epoch: 0284 cost = 0.013380535
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0285 cost = 0.012606684
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0286 cost = 0.013533472
# Validation Error: 0.0121999979019
# Epoch: 0287 cost = 0.014016470
# Validation Error: 0.0120000243187
# Epoch: 0288 cost = 0.015842247
# Validation Error: 0.0113999843597
# Epoch: 0289 cost = 0.013302872
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0290 cost = 0.016112096
# Validation Error: 0.0112000107765
# Epoch: 0291 cost = 0.014547153
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0292 cost = 0.013269988
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0293 cost = 0.014244572
# Validation Error: 0.0127999782562
# Epoch: 0294 cost = 0.013758244
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0295 cost = 0.016281466
# Validation Error: 0.0117999911308
# Epoch: 0296 cost = 0.015128290
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0297 cost = 0.013486371
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0298 cost = 0.014809382
# Validation Error: 0.0112000107765
# Epoch: 0299 cost = 0.013424116
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0300 cost = 0.015048050
# Validation Error: 0.0123999714851
# Epoch: 0301 cost = 0.012889889
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0302 cost = 0.013246713
# Validation Error: 0.012600004673
# Epoch: 0303 cost = 0.013256464
# Validation Error: 0.0113999843597
# Epoch: 0304 cost = 0.014731447
# Validation Error: 0.0112000107765
# Epoch: 0305 cost = 0.014602512
# Validation Error: 0.0127999782562
# overfitting warning:0
# Epoch: 0306 cost = 0.014944679
# Validation Error: 0.0108000040054
# Epoch: 0307 cost = 0.016376958
# Validation Error: 0.0108000040054
# Epoch: 0308 cost = 0.015429695
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0309 cost = 0.013815277
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0310 cost = 0.012820398
# Validation Error: 0.0112000107765
# overfitting warning:2
# Epoch: 0311 cost = 0.013734832
# Validation Error: 0.00980001688004
# Epoch: 0312 cost = 0.013123490
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0313 cost = 0.013503705
# Validation Error: 0.00980001688004
# Epoch: 0314 cost = 0.015625092
# Validation Error: 0.0108000040054
# Epoch: 0315 cost = 0.014465600
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0316 cost = 0.011485018
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0317 cost = 0.014253540
# Validation Error: 0.0112000107765
# Epoch: 0318 cost = 0.013107767
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0319 cost = 0.014690281
# Validation Error: 0.0120000243187
# Epoch: 0320 cost = 0.013878404
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0321 cost = 0.017222683
# Validation Error: 0.0108000040054
# Epoch: 0322 cost = 0.012583710
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0323 cost = 0.014153658
# Validation Error: 0.0109999775887
# Epoch: 0324 cost = 0.013963866
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0325 cost = 0.012763919
# Validation Error: 0.00959998369217
# Epoch: 0326 cost = 0.016556223
# Validation Error: 0.0117999911308
# Epoch: 0327 cost = 0.015615248
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0328 cost = 0.017350073
# Validation Error: 0.0116000175476
# Epoch: 0329 cost = 0.013098737
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0330 cost = 0.013439658
# Validation Error: 0.0105999708176
# Epoch: 0331 cost = 0.013321464
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0332 cost = 0.015720371
# Validation Error: 0.00999999046326
# Epoch: 0333 cost = 0.013947315
# Validation Error: 0.00940001010895
# Epoch: 0334 cost = 0.012546747
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0335 cost = 0.014249928
# Validation Error: 0.0116000175476
# Epoch: 0336 cost = 0.014182706
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0337 cost = 0.015174383
# Validation Error: 0.0112000107765
# Epoch: 0338 cost = 0.012959558
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0339 cost = 0.013792320
# Validation Error: 0.0113999843597
# Epoch: 0340 cost = 0.013277969
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0341 cost = 0.014759256
# Validation Error: 0.0112000107765
# Epoch: 0342 cost = 0.013099334
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0343 cost = 0.016242876
# Validation Error: 0.0103999972343
# Epoch: 0344 cost = 0.013142602
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0345 cost = 0.013250408
# Validation Error: 0.0121999979019
# Epoch: 0346 cost = 0.012909142
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0347 cost = 0.014532726
# Validation Error: 0.0113999843597
# Epoch: 0348 cost = 0.014462984
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0349 cost = 0.014421737
# Validation Error: 0.0109999775887
# overfitting warning:1
# Epoch: 0350 cost = 0.012104265
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0351 cost = 0.015544646
# Validation Error: 0.0109999775887
# Epoch: 0352 cost = 0.013141767
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0353 cost = 0.013141038
# Validation Error: 0.0103999972343
# overfitting warning:1
# Epoch: 0354 cost = 0.014194843
# Validation Error: 0.0113999843597
# Epoch: 0355 cost = 0.011554074
# Validation Error: 0.0127999782562
# overfitting warning:0
# Epoch: 0356 cost = 0.013857106
# Validation Error: 0.0116000175476
# Epoch: 0357 cost = 0.013964045
# Validation Error: 0.00999999046326
# Epoch: 0358 cost = 0.013768799
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0359 cost = 0.014536678
# Validation Error: 0.0116000175476
# Epoch: 0360 cost = 0.014399545
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0361 cost = 0.015704951
# Validation Error: 0.0120000243187
# Epoch: 0362 cost = 0.013976494
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0363 cost = 0.015031986
# Validation Error: 0.0130000114441
# Epoch: 0364 cost = 0.013436377
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0365 cost = 0.015196044
# Validation Error: 0.0109999775887
# Epoch: 0366 cost = 0.014816967
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0367 cost = 0.013632673
# Validation Error: 0.00940001010895
# Epoch: 0368 cost = 0.016501403
# Validation Error: 0.0102000236511
# Epoch: 0369 cost = 0.013877957
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0370 cost = 0.013910279
# Validation Error: 0.0105999708176
# Epoch: 0371 cost = 0.013648928
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0372 cost = 0.014139626
# Validation Error: 0.0113999843597
# Epoch: 0373 cost = 0.010646794
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0374 cost = 0.014090080
# Validation Error: 0.0121999979019
# Epoch: 0375 cost = 0.012670733
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0376 cost = 0.014265402
# Validation Error: 0.0116000175476
# Epoch: 0377 cost = 0.014175189
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0378 cost = 0.013594604
# Validation Error: 0.0108000040054
# overfitting warning:1
# Epoch: 0379 cost = 0.014776569
# Validation Error: 0.0120000243187
# Epoch: 0380 cost = 0.015937795
# Validation Error: 0.0108000040054
# Epoch: 0381 cost = 0.012223745
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0382 cost = 0.015383914
# Validation Error: 0.0121999979019
# Epoch: 0383 cost = 0.014675215
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0384 cost = 0.014448488
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0385 cost = 0.013451120
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0386 cost = 0.016400067
# Validation Error: 0.0105999708176
# Epoch: 0387 cost = 0.011521695
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0388 cost = 0.016002546
# Validation Error: 0.0116000175476
# Epoch: 0389 cost = 0.014483178
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0390 cost = 0.016161074
# Validation Error: 0.0112000107765
# Epoch: 0391 cost = 0.013856520
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0392 cost = 0.014973566
# Validation Error: 0.0102000236511
# Epoch: 0393 cost = 0.014080282
# Validation Error: 0.0130000114441
# overfitting warning:0
# Epoch: 0394 cost = 0.013500337
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0395 cost = 0.013734632
# Validation Error: 0.0103999972343
# Epoch: 0396 cost = 0.013954830
# Validation Error: 0.0121999979019
# Epoch: 0397 cost = 0.013209065
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0398 cost = 0.015399398
# Validation Error: 0.00980001688004
# Epoch: 0399 cost = 0.013935016
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0400 cost = 0.013749647
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0401 cost = 0.012730615
# Validation Error: 0.0116000175476
# overfitting warning:2
# Epoch: 0402 cost = 0.014275183
# Validation Error: 0.0116000175476
# Epoch: 0403 cost = 0.014768409
# Validation Error: 0.0120000243187
# Epoch: 0404 cost = 0.013272546
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0405 cost = 0.014076368
# Validation Error: 0.0105999708176
# Epoch: 0406 cost = 0.014738844
# Validation Error: 0.0116000175476
# Epoch: 0407 cost = 0.015601193
# Validation Error: 0.0109999775887
# Epoch: 0408 cost = 0.015797695
# Validation Error: 0.0112000107765
# Epoch: 0409 cost = 0.013825546
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0410 cost = 0.014395431
# Validation Error: 0.0109999775887
# Epoch: 0411 cost = 0.014943816
# Validation Error: 0.0116000175476
# Epoch: 0412 cost = 0.012670875
# Validation Error: 0.0130000114441
# overfitting warning:0
# Epoch: 0413 cost = 0.013332302
# Validation Error: 0.0113999843597
# Epoch: 0414 cost = 0.013273341
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0415 cost = 0.013231171
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0416 cost = 0.015616923
# Validation Error: 0.0113999843597
# Epoch: 0417 cost = 0.012657494
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0418 cost = 0.012267376
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0419 cost = 0.012214293
# Validation Error: 0.0116000175476
# overfitting warning:2
# Epoch: 0420 cost = 0.013874461
# Validation Error: 0.0112000107765
# Epoch: 0421 cost = 0.014665769
# Validation Error: 0.0108000040054
# Epoch: 0422 cost = 0.015195909
# Validation Error: 0.0112000107765
# Epoch: 0423 cost = 0.015323618
# Validation Error: 0.0105999708176
# Epoch: 0424 cost = 0.014066042
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0425 cost = 0.012516408
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0426 cost = 0.012962777
# Validation Error: 0.0112000107765
# Epoch: 0427 cost = 0.015809665
# Validation Error: 0.0123999714851
# Epoch: 0428 cost = 0.013554755
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0429 cost = 0.015453595
# Validation Error: 0.0113999843597
# Epoch: 0430 cost = 0.011678040
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0431 cost = 0.012296648
# Validation Error: 0.0117999911308
# Epoch: 0432 cost = 0.015361801
# Validation Error: 0.0116000175476
# Epoch: 0433 cost = 0.013585958
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0434 cost = 0.012139341
# Validation Error: 0.0123999714851
# overfitting warning:1
# Epoch: 0435 cost = 0.013361530
# Validation Error: 0.0113999843597
# Epoch: 0436 cost = 0.013646459
# Validation Error: 0.0108000040054
# Epoch: 0437 cost = 0.014863402
# Validation Error: 0.0108000040054
# Epoch: 0438 cost = 0.013828544
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0439 cost = 0.015793146
# Validation Error: 0.0112000107765
# Epoch: 0440 cost = 0.013409037
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0441 cost = 0.013907721
# Validation Error: 0.0116000175476
# Epoch: 0442 cost = 0.013318044
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0443 cost = 0.015156335
# Validation Error: 0.0113999843597
# Epoch: 0444 cost = 0.012735100
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0445 cost = 0.012542948
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0446 cost = 0.013628310
# Validation Error: 0.0116000175476
# Epoch: 0447 cost = 0.015038017
# Validation Error: 0.012600004673
# Epoch: 0448 cost = 0.013566487
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0449 cost = 0.014419866
# Validation Error: 0.0116000175476
# Epoch: 0450 cost = 0.012774057
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0451 cost = 0.012314074
# Validation Error: 0.0139999985695
# overfitting warning:1
# Epoch: 0452 cost = 0.012426606
# Validation Error: 0.0116000175476
# Epoch: 0453 cost = 0.013914481
# Validation Error: 0.0116000175476
# Epoch: 0454 cost = 0.014773576
# Validation Error: 0.0116000175476
# Epoch: 0455 cost = 0.013768873
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0456 cost = 0.010991201
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0457 cost = 0.012932641
# Validation Error: 0.0108000040054
# Epoch: 0458 cost = 0.013170211
# Validation Error: 0.0112000107765
# Epoch: 0459 cost = 0.013568626
# Validation Error: 0.0117999911308
# Epoch: 0460 cost = 0.013224316
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0461 cost = 0.013820568
# Validation Error: 0.0117999911308
# Epoch: 0462 cost = 0.011915684
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0463 cost = 0.013536801
# Validation Error: 0.0123999714851
# Epoch: 0464 cost = 0.011742693
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0465 cost = 0.014178458
# Validation Error: 0.0121999979019
# Epoch: 0466 cost = 0.014569377
# Validation Error: 0.0105999708176
# Epoch: 0467 cost = 0.013626078
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0468 cost = 0.012079473
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0469 cost = 0.011627629
# Validation Error: 0.0134000182152
# overfitting warning:2
# Epoch: 0470 cost = 0.012883818
# Validation Error: 0.0109999775887
# Epoch: 0471 cost = 0.013436104
# Validation Error: 0.0127999782562
# Epoch: 0472 cost = 0.013528020
# Validation Error: 0.0121999979019
# Epoch: 0473 cost = 0.013241045
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0474 cost = 0.013594315
# Validation Error: 0.0105999708176
# Epoch: 0475 cost = 0.013793859
# Validation Error: 0.0103999972343
# Epoch: 0476 cost = 0.013168563
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0477 cost = 0.012747568
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0478 cost = 0.013095730
# Validation Error: 0.0134000182152
# Epoch: 0479 cost = 0.012631897
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0480 cost = 0.012298897
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0481 cost = 0.014919907
# Validation Error: 0.0113999843597
# Epoch: 0482 cost = 0.013152704
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0483 cost = 0.011375239
# Validation Error: 0.0105999708176
# overfitting warning:1
# Epoch: 0484 cost = 0.012041426
# Validation Error: 0.0130000114441
# Epoch: 0485 cost = 0.013513485
# Validation Error: 0.0130000114441
# Epoch: 0486 cost = 0.012658288
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0487 cost = 0.012214009
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0488 cost = 0.013099350
# Validation Error: 0.0109999775887
# Epoch: 0489 cost = 0.012895887
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0490 cost = 0.013513159
# Validation Error: 0.0117999911308
# Epoch: 0491 cost = 0.011818590
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0492 cost = 0.013077670
# Validation Error: 0.0116000175476
# Epoch: 0493 cost = 0.013969250
# Validation Error: 0.0123999714851
# Epoch: 0494 cost = 0.013549610
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0495 cost = 0.014519399
# Validation Error: 0.0121999979019
# Epoch: 0496 cost = 0.014841495
# Validation Error: 0.0116000175476
# Epoch: 0497 cost = 0.014066127
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0498 cost = 0.012114722
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0499 cost = 0.012584988
# Validation Error: 0.0113999843597
# Epoch: 0500 cost = 0.014455298
# Validation Error: 0.0123999714851
# Epoch: 0501 cost = 0.010989235
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0502 cost = 0.012429314
# Validation Error: 0.0121999979019
# Epoch: 0503 cost = 0.012979323
# Validation Error: 0.0121999979019
# Epoch: 0504 cost = 0.015838163
# Validation Error: 0.0112000107765
# Epoch: 0505 cost = 0.013458882
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0506 cost = 0.013482224
# Validation Error: 0.0123999714851
# Epoch: 0507 cost = 0.012754986
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0508 cost = 0.012233562
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0509 cost = 0.013609669
# Validation Error: 0.0123999714851
# Epoch: 0510 cost = 0.015360163
# Validation Error: 0.0105999708176
# Epoch: 0511 cost = 0.013789136
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0512 cost = 0.014402662
# Validation Error: 0.012600004673
# Epoch: 0513 cost = 0.014056984
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0514 cost = 0.014214008
# Validation Error: 0.0116000175476
# Epoch: 0515 cost = 0.012666278
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0516 cost = 0.012385866
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0517 cost = 0.012239160
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0518 cost = 0.012645691
# Validation Error: 0.0102000236511
# Epoch: 0519 cost = 0.012557927
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0520 cost = 0.015140560
# Validation Error: 0.0121999979019
# Epoch: 0521 cost = 0.012081725
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0522 cost = 0.011746437
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0523 cost = 0.014389607
# Validation Error: 0.0105999708176
# Epoch: 0524 cost = 0.012306317
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0525 cost = 0.012184303
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0526 cost = 0.012849142
# Validation Error: 0.0108000040054
# Epoch: 0527 cost = 0.013493488
# Validation Error: 0.0117999911308
# Epoch: 0528 cost = 0.013161753
# Validation Error: 0.00959998369217
# overfitting warning:0
# Epoch: 0529 cost = 0.012471253
# Validation Error: 0.0108000040054
# overfitting warning:1
# Epoch: 0530 cost = 0.011551440
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0531 cost = 0.011666272
# Validation Error: 0.0123999714851
# Epoch: 0532 cost = 0.013505962
# Validation Error: 0.0127999782562
# Epoch: 0533 cost = 0.014371337
# Validation Error: 0.0108000040054
# Epoch: 0534 cost = 0.014072907
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0535 cost = 0.014814310
# Validation Error: 0.0112000107765
# Epoch: 0536 cost = 0.013709542
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0537 cost = 0.013174944
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0538 cost = 0.012811167
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0539 cost = 0.010907112
# Validation Error: 0.0112000107765
# overfitting warning:3
# Epoch: 0540 cost = 0.014213994
# Validation Error: 0.0109999775887
# Epoch: 0541 cost = 0.011904888
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0542 cost = 0.012629368
# Validation Error: 0.0103999972343
# Epoch: 0543 cost = 0.015551432
# Validation Error: 0.0117999911308
# Epoch: 0544 cost = 0.011640715
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0545 cost = 0.013226510
# Validation Error: 0.0117999911308
# Epoch: 0546 cost = 0.015556396
# Validation Error: 0.012600004673
# Epoch: 0547 cost = 0.013673201
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0548 cost = 0.011124363
# Validation Error: 0.0130000114441
# overfitting warning:1
# Epoch: 0549 cost = 0.012441617
# Validation Error: 0.0113999843597
# Epoch: 0550 cost = 0.012805251
# Validation Error: 0.0121999979019
# Epoch: 0551 cost = 0.013395240
# Validation Error: 0.0105999708176
# Epoch: 0552 cost = 0.012511858
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0553 cost = 0.012738377
# Validation Error: 0.0112000107765
# Epoch: 0554 cost = 0.014572694
# Validation Error: 0.0127999782562
# Epoch: 0555 cost = 0.014135923
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0556 cost = 0.013486711
# Validation Error: 0.0130000114441
# overfitting warning:1
# Epoch: 0557 cost = 0.013787862
# Validation Error: 0.0116000175476
# Epoch: 0558 cost = 0.014871474
# Validation Error: 0.0108000040054
# Epoch: 0559 cost = 0.013162313
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0560 cost = 0.012668485
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0561 cost = 0.011833016
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0562 cost = 0.015053897
# Validation Error: 0.0112000107765
# Epoch: 0563 cost = 0.014849955
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0564 cost = 0.014358443
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0565 cost = 0.012593575
# Validation Error: 0.0123999714851
# overfitting warning:2
# Epoch: 0566 cost = 0.012096781
# Validation Error: 0.0116000175476
# overfitting warning:3
# Epoch: 0567 cost = 0.014221669
# Validation Error: 0.0113999843597
# Epoch: 0568 cost = 0.014704506
# Validation Error: 0.0103999972343
# Epoch: 0569 cost = 0.012677298
# Validation Error: 0.00959998369217
# overfitting warning:0
# Epoch: 0570 cost = 0.012699583
# Validation Error: 0.012600004673
# Epoch: 0571 cost = 0.011661950
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0572 cost = 0.013412463
# Validation Error: 0.0121999979019
# Epoch: 0573 cost = 0.014138645
# Validation Error: 0.0112000107765
# Epoch: 0574 cost = 0.012130573
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0575 cost = 0.012701167
# Validation Error: 0.0105999708176
# Epoch: 0576 cost = 0.013379145
# Validation Error: 0.0130000114441
# Epoch: 0577 cost = 0.013203799
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0578 cost = 0.014690018
# Validation Error: 0.0103999972343
# Epoch: 0579 cost = 0.014137537
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0580 cost = 0.013309292
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0581 cost = 0.012359966
# Validation Error: 0.0109999775887
# overfitting warning:2
# Epoch: 0582 cost = 0.012194947
# Validation Error: 0.0113999843597
# overfitting warning:3
# Epoch: 0583 cost = 0.013766571
# Validation Error: 0.0121999979019
# Epoch: 0584 cost = 0.013796217
# Validation Error: 0.0109999775887
# Epoch: 0585 cost = 0.014394715
# Validation Error: 0.0108000040054
# Epoch: 0586 cost = 0.011694631
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0587 cost = 0.013731539
# Validation Error: 0.0108000040054
# Epoch: 0588 cost = 0.012173352
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0589 cost = 0.012054520
# Validation Error: 0.0103999972343
# overfitting warning:1
# Epoch: 0590 cost = 0.015129613
# Validation Error: 0.0112000107765
# Epoch: 0591 cost = 0.014497665
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0592 cost = 0.011267404
# Validation Error: 0.0123999714851
# overfitting warning:1
# Epoch: 0593 cost = 0.014626956
# Validation Error: 0.0112000107765
# Epoch: 0594 cost = 0.013655284
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0595 cost = 0.011184898
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0596 cost = 0.015533595
# Validation Error: 0.0117999911308
# Epoch: 0597 cost = 0.012720244
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0598 cost = 0.013806220
# Validation Error: 0.0116000175476
# Epoch: 0599 cost = 0.011847241
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0600 cost = 0.013351486
# Validation Error: 0.0130000114441
# Epoch: 0601 cost = 0.012552713
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0602 cost = 0.012782431
# Validation Error: 0.0109999775887
# Epoch: 0603 cost = 0.012987322
# Validation Error: 0.00999999046326
# Epoch: 0604 cost = 0.012826365
# Validation Error: 0.0127999782562
# overfitting warning:0
# Epoch: 0605 cost = 0.012703561
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0606 cost = 0.011775853
# Validation Error: 0.0113999843597
# overfitting warning:2
# Epoch: 0607 cost = 0.014577566
# Validation Error: 0.0113999843597
# Epoch: 0608 cost = 0.012200657
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0609 cost = 0.013688922
# Validation Error: 0.0113999843597
# Epoch: 0610 cost = 0.012505453
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0611 cost = 0.013220815
# Validation Error: 0.0105999708176
# Epoch: 0612 cost = 0.013737830
# Validation Error: 0.0105999708176
# Epoch: 0613 cost = 0.013352696
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0614 cost = 0.013336492
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0615 cost = 0.014393369
# Validation Error: 0.0112000107765
# Epoch: 0616 cost = 0.014628106
# Validation Error: 0.0113999843597
# Epoch: 0617 cost = 0.012466159
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0618 cost = 0.012751847
# Validation Error: 0.0131999850273
# Epoch: 0619 cost = 0.012528790
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0620 cost = 0.014885362
# Validation Error: 0.0109999775887
# Epoch: 0621 cost = 0.012468204
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0622 cost = 0.012971133
# Validation Error: 0.0116000175476
# Epoch: 0623 cost = 0.011898046
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0624 cost = 0.013071103
# Validation Error: 0.0117999911308
# Epoch: 0625 cost = 0.012020371
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0626 cost = 0.014117610
# Validation Error: 0.0116000175476
# Epoch: 0627 cost = 0.013575507
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0628 cost = 0.012466744
# Validation Error: 0.0130000114441
# overfitting warning:1
# Epoch: 0629 cost = 0.012893906
# Validation Error: 0.0121999979019
# Epoch: 0630 cost = 0.013306207
# Validation Error: 0.0116000175476
# Epoch: 0631 cost = 0.012259192
# Validation Error: 0.0102000236511
# overfitting warning:0
# ...
# Validation Error: 0.0112000107765
# Epoch: 0792 cost = 0.014110292
# Validation Error: 0.0117999911308
# Epoch: 0793 cost = 0.013009903
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0794 cost = 0.013468789
# Validation Error: 0.0112000107765
# Epoch: 0795 cost = 0.011962241
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0796 cost = 0.013452355
# Validation Error: 0.0103999972343
# Epoch: 0797 cost = 0.012081076
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0798 cost = 0.012442286
# Validation Error: 0.0120000243187
# Epoch: 0799 cost = 0.011352920
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0800 cost = 0.012598882
# Validation Error: 0.0113999843597
# Epoch: 0801 cost = 0.013036538
# Validation Error: 0.0103999972343
# Epoch: 0802 cost = 0.011830555
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0803 cost = 0.012894497
# Validation Error: 0.00999999046326
# Epoch: 0804 cost = 0.012581476
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0805 cost = 0.012290621
# Validation Error: 0.0105999708176
# overfitting warning:1
# Epoch: 0806 cost = 0.011903846
# Validation Error: 0.0112000107765
# overfitting warning:2
# Epoch: 0807 cost = 0.011769568
# Validation Error: 0.0116000175476
# overfitting warning:3
# Epoch: 0808 cost = 0.013425914
# Validation Error: 0.0113999843597
# Epoch: 0809 cost = 0.012286593
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0810 cost = 0.012432696
# Validation Error: 0.0102000236511
# Epoch: 0811 cost = 0.012443414
# Validation Error: 0.0112000107765
# Epoch: 0812 cost = 0.014260723
# Validation Error: 0.0112000107765
# Epoch: 0813 cost = 0.013345762
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0814 cost = 0.013195570
# Validation Error: 0.0108000040054
# overfitting warning:1
# Epoch: 0815 cost = 0.011605671
# Validation Error: 0.0113999843597
# overfitting warning:2
# Epoch: 0816 cost = 0.012322900
# Validation Error: 0.0108000040054
# Epoch: 0817 cost = 0.013520040
# Validation Error: 0.012600004673
# Epoch: 0818 cost = 0.011824820
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0819 cost = 0.013690535
# Validation Error: 0.0113999843597
# Epoch: 0820 cost = 0.012158628
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0821 cost = 0.014191416
# Validation Error: 0.0112000107765
# Epoch: 0822 cost = 0.012659357
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0823 cost = 0.013485570
# Validation Error: 0.0120000243187
# Epoch: 0824 cost = 0.012038043
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0825 cost = 0.013163458
# Validation Error: 0.0121999979019
# Epoch: 0826 cost = 0.012208688
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0827 cost = 0.012403481
# Validation Error: 0.0123999714851
# Epoch: 0828 cost = 0.013937170
# Validation Error: 0.0130000114441
# Epoch: 0829 cost = 0.013327210
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0830 cost = 0.013136271
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0831 cost = 0.013694244
# Validation Error: 0.0117999911308
# Epoch: 0832 cost = 0.012138039
# Validation Error: 0.0130000114441
# overfitting warning:0
# Epoch: 0833 cost = 0.013979965
# Validation Error: 0.0121999979019
# Epoch: 0834 cost = 0.013257036
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0835 cost = 0.014718123
# Validation Error: 0.0108000040054
# Epoch: 0836 cost = 0.012258076
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0837 cost = 0.013454568
# Validation Error: 0.0108000040054
# Epoch: 0838 cost = 0.011931273
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0839 cost = 0.013462350
# Validation Error: 0.0102000236511
# Epoch: 0840 cost = 0.013231332
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0841 cost = 0.014263875
# Validation Error: 0.0103999972343
# Epoch: 0842 cost = 0.014637307
# Validation Error: 0.0109999775887
# Epoch: 0843 cost = 0.014931558
# Validation Error: 0.0112000107765
# Epoch: 0844 cost = 0.013282849
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0845 cost = 0.012035280
# Validation Error: 0.00980001688004
# overfitting warning:1
# Epoch: 0846 cost = 0.015139452
# Validation Error: 0.0121999979019
# Epoch: 0847 cost = 0.012944471
# Validation Error: 0.0121999979019
# overfitting warning:0
# Epoch: 0848 cost = 0.010628297
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0849 cost = 0.013399608
# Validation Error: 0.0108000040054
# Epoch: 0850 cost = 0.012097642
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0851 cost = 0.011712133
# Validation Error: 0.0123999714851
# overfitting warning:1
# Epoch: 0852 cost = 0.011488475
# Validation Error: 0.0112000107765
# overfitting warning:2
# Epoch: 0853 cost = 0.010941668
# Validation Error: 0.0112000107765
# overfitting warning:3
# Epoch: 0854 cost = 0.012593730
# Validation Error: 0.0116000175476
# Epoch: 0855 cost = 0.011785834
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0856 cost = 0.013020155
# Validation Error: 0.0109999775887
# Epoch: 0857 cost = 0.011692800
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0858 cost = 0.011629675
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0859 cost = 0.011987298
# Validation Error: 0.0112000107765
# Epoch: 0860 cost = 0.014524906
# Validation Error: 0.0105999708176
# Epoch: 0861 cost = 0.014390350
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0862 cost = 0.013544622
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0863 cost = 0.011956045
# Validation Error: 0.0108000040054
# overfitting warning:2
# Epoch: 0864 cost = 0.012651359
# Validation Error: 0.0116000175476
# Epoch: 0865 cost = 0.010820956
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0866 cost = 0.012574363
# Validation Error: 0.00999999046326
# Epoch: 0867 cost = 0.010501639
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0868 cost = 0.013732254
# Validation Error: 0.0121999979019
# Epoch: 0869 cost = 0.014914639
# Validation Error: 0.0112000107765
# Epoch: 0870 cost = 0.010861436
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0871 cost = 0.013434576
# Validation Error: 0.0102000236511
# Epoch: 0872 cost = 0.014254285
# Validation Error: 0.0109999775887
# Epoch: 0873 cost = 0.013645894
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0874 cost = 0.013315948
# Validation Error: 0.0109999775887
# overfitting warning:1
# Epoch: 0875 cost = 0.013751811
# Validation Error: 0.0109999775887
# Epoch: 0876 cost = 0.011283204
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0877 cost = 0.011193516
# Validation Error: 0.0116000175476
# overfitting warning:1
# Epoch: 0878 cost = 0.011555335
# Validation Error: 0.0108000040054
# Epoch: 0879 cost = 0.014087021
# Validation Error: 0.00999999046326
# Epoch: 0880 cost = 0.012839961
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0881 cost = 0.010708626
# Validation Error: 0.0103999972343
# overfitting warning:1
# Epoch: 0882 cost = 0.010975517
# Validation Error: 0.0103999972343
# Epoch: 0883 cost = 0.013655512
# Validation Error: 0.0108000040054
# Epoch: 0884 cost = 0.013301828
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0885 cost = 0.011766017
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0886 cost = 0.011551874
# Validation Error: 0.0113999843597
# overfitting warning:2
# Epoch: 0887 cost = 0.011076241
# Validation Error: 0.0123999714851
# overfitting warning:3
# Epoch: 0888 cost = 0.013384504
# Validation Error: 0.0112000107765
# Epoch: 0889 cost = 0.015338066
# Validation Error: 0.0113999843597
# Epoch: 0890 cost = 0.012843155
# Validation Error: 0.0105999708176
# overfitting warning:0
# Epoch: 0891 cost = 0.013036039
# Validation Error: 0.0113999843597
# Epoch: 0892 cost = 0.011416364
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0893 cost = 0.013133131
# Validation Error: 0.0113999843597
# Epoch: 0894 cost = 0.013899598
# Validation Error: 0.0120000243187
# Epoch: 0895 cost = 0.009975593
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0896 cost = 0.011771515
# Validation Error: 0.0120000243187
# Epoch: 0897 cost = 0.012370504
# Validation Error: 0.0117999911308
# Epoch: 0898 cost = 0.011800582
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0899 cost = 0.012848568
# Validation Error: 0.0112000107765
# Epoch: 0900 cost = 0.011671391
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0901 cost = 0.012286438
# Validation Error: 0.0120000243187
# Epoch: 0902 cost = 0.012040334
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0903 cost = 0.012559998
# Validation Error: 0.0113999843597
# Epoch: 0904 cost = 0.012316585
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0905 cost = 0.013526018
# Validation Error: 0.0134000182152
# Epoch: 0906 cost = 0.012090265
# Validation Error: 0.0130000114441
# overfitting warning:0
# Epoch: 0907 cost = 0.012641274
# Validation Error: 0.0134000182152
# Epoch: 0908 cost = 0.013737363
# Validation Error: 0.0117999911308
# Epoch: 0909 cost = 0.012128418
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0910 cost = 0.012616506
# Validation Error: 0.012600004673
# Epoch: 0911 cost = 0.012505034
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0912 cost = 0.013171403
# Validation Error: 0.012600004673
# Epoch: 0913 cost = 0.011408366
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0914 cost = 0.011446898
# Validation Error: 0.00980001688004
# Epoch: 0915 cost = 0.013176080
# Validation Error: 0.0113999843597
# Epoch: 0916 cost = 0.014932787
# Validation Error: 0.0116000175476
# Epoch: 0917 cost = 0.013207347
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0918 cost = 0.013890707
# Validation Error: 0.0105999708176
# Epoch: 0919 cost = 0.014842591
# Validation Error: 0.0121999979019
# Epoch: 0920 cost = 0.011683938
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0921 cost = 0.012690968
# Validation Error: 0.0121999979019
# Epoch: 0922 cost = 0.011905884
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0923 cost = 0.010914969
# Validation Error: 0.0113999843597
# overfitting warning:1
# Epoch: 0924 cost = 0.013379089
# Validation Error: 0.0108000040054
# Epoch: 0925 cost = 0.013349817
# Validation Error: 0.00980001688004
# overfitting warning:0
# Epoch: 0926 cost = 0.011705009
# Validation Error: 0.0109999775887
# overfitting warning:1
# Epoch: 0927 cost = 0.014361523
# Validation Error: 0.0112000107765
# Epoch: 0928 cost = 0.009680438
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0929 cost = 0.012626970
# Validation Error: 0.0121999979019
# Epoch: 0930 cost = 0.012915462
# Validation Error: 0.0109999775887
# Epoch: 0931 cost = 0.012750872
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0932 cost = 0.011697607
# Validation Error: 0.0131999850273
# overfitting warning:1
# Epoch: 0933 cost = 0.011405397
# Validation Error: 0.0112000107765
# overfitting warning:2
# Epoch: 0934 cost = 0.011822481
# Validation Error: 0.0116000175476
# Epoch: 0935 cost = 0.011762936
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0936 cost = 0.013279466
# Validation Error: 0.0123999714851
# Epoch: 0937 cost = 0.012431149
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0938 cost = 0.012115464
# Validation Error: 0.0121999979019
# overfitting warning:1
# Epoch: 0939 cost = 0.012593625
# Validation Error: 0.0120000243187
# Epoch: 0940 cost = 0.012738520
# Validation Error: 0.0113999843597
# Epoch: 0941 cost = 0.012368536
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0942 cost = 0.011479489
# Validation Error: 0.0105999708176
# overfitting warning:1
# Epoch: 0943 cost = 0.013418147
# Validation Error: 0.0112000107765
# Epoch: 0944 cost = 0.014164999
# Validation Error: 0.0112000107765
# Epoch: 0945 cost = 0.012233598
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0946 cost = 0.013063135
# Validation Error: 0.0117999911308
# Epoch: 0947 cost = 0.012480473
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0948 cost = 0.011444054
# Validation Error: 0.0112000107765
# overfitting warning:1
# Epoch: 0949 cost = 0.012393347
# Validation Error: 0.0103999972343
# Epoch: 0950 cost = 0.012249076
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0951 cost = 0.012717309
# Validation Error: 0.0116000175476
# Epoch: 0952 cost = 0.012676961
# Validation Error: 0.0113999843597
# overfitting warning:0
# Epoch: 0953 cost = 0.012310199
# Validation Error: 0.0117999911308
# overfitting warning:1
# Epoch: 0954 cost = 0.011558289
# Validation Error: 0.0120000243187
# overfitting warning:2
# Epoch: 0955 cost = 0.011646078
# Validation Error: 0.0112000107765
# Epoch: 0956 cost = 0.013907294
# Validation Error: 0.0121999979019
# Epoch: 0957 cost = 0.014456726
# Validation Error: 0.0127999782562
# Epoch: 0958 cost = 0.011746807
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0959 cost = 0.013293128
# Validation Error: 0.0116000175476
# Epoch: 0960 cost = 0.010301441
# Validation Error: 0.012600004673
# overfitting warning:0
# Epoch: 0961 cost = 0.012469408
# Validation Error: 0.0123999714851
# Epoch: 0962 cost = 0.012163053
# Validation Error: 0.0120000243187
# overfitting warning:0
# Epoch: 0963 cost = 0.017408148
# Validation Error: 0.0131999850273
# Epoch: 0964 cost = 0.013094319
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0965 cost = 0.012104217
# Validation Error: 0.0102000236511
# overfitting warning:1
# Epoch: 0966 cost = 0.012576644
# Validation Error: 0.0121999979019
# Epoch: 0967 cost = 0.014871247
# Validation Error: 0.0108000040054
# Epoch: 0968 cost = 0.013852215
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0969 cost = 0.014396274
# Validation Error: 0.012600004673
# Epoch: 0970 cost = 0.012325044
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0971 cost = 0.012169840
# Validation Error: 0.0120000243187
# overfitting warning:1
# Epoch: 0972 cost = 0.013955576
# Validation Error: 0.0112000107765
# Epoch: 0973 cost = 0.012238722
# Validation Error: 0.0117999911308
# overfitting warning:0
# Epoch: 0974 cost = 0.011156065
# Validation Error: 0.012600004673
# overfitting warning:1
# Epoch: 0975 cost = 0.011676517
# Validation Error: 0.0131999850273
# Epoch: 0976 cost = 0.011368075
# Validation Error: 0.0109999775887
# overfitting warning:0
# Epoch: 0977 cost = 0.011873511
# Validation Error: 0.00980001688004
# Epoch: 0978 cost = 0.012487256
# Validation Error: 0.0105999708176
# Epoch: 0979 cost = 0.012795239
# Validation Error: 0.0131999850273
# Epoch: 0980 cost = 0.011812410
# Validation Error: 0.00999999046326
# overfitting warning:0
# Epoch: 0981 cost = 0.015797976
# Validation Error: 0.0113999843597
# Epoch: 0982 cost = 0.012673940
# Validation Error: 0.0123999714851
# overfitting warning:0
# Epoch: 0983 cost = 0.013988890
# Validation Error: 0.0105999708176
# Epoch: 0984 cost = 0.012551885
# Validation Error: 0.0103999972343
# overfitting warning:0
# Epoch: 0985 cost = 0.012256627
# Validation Error: 0.0103999972343
# overfitting warning:1
# Epoch: 0986 cost = 0.012487372
# Validation Error: 0.0109999775887
# Epoch: 0987 cost = 0.011656959
# Validation Error: 0.0102000236511
# overfitting warning:0
# Epoch: 0988 cost = 0.012944050
# Validation Error: 0.0103999972343
# Epoch: 0989 cost = 0.013028558
# Validation Error: 0.0109999775887
# Epoch: 0990 cost = 0.012949263
# Validation Error: 0.0112000107765
# overfitting warning:0
# Epoch: 0991 cost = 0.013516358
# Validation Error: 0.0112000107765
# Epoch: 0992 cost = 0.011367168
# Validation Error: 0.0108000040054
# overfitting warning:0
# Epoch: 0993 cost = 0.011984182
# Validation Error: 0.0112000107765
# Epoch: 0994 cost = 0.012499618
# Validation Error: 0.0123999714851
# Epoch: 0995 cost = 0.014654240
# Validation Error: 0.0112000107765
# Epoch: 0996 cost = 0.014279760
# Validation Error: 0.0116000175476
# overfitting warning:0
# Epoch: 0997 cost = 0.010605171
# Validation Error: 0.0102000236511
# overfitting warning:1
# Epoch: 0998 cost = 0.012501030
# Validation Error: 0.0112000107765
# Epoch: 0999 cost = 0.014214566
# Validation Error: 0.0109999775887
# Epoch: 1000 cost = 0.014275575
# Validation Error: 0.0109999775887
# Optimization Done
# Test Accuracy: 0.9882
# Execution time was 1767.900
